# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('/Users/alvinsamueljeyachander/Downloads/SpotifyFeatures.csv')
df_tracks.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
#check for null values

# %%
pd.isnull(df_tracks).sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %%
#10 least popular songs

# %%
sorted_df = df_tracks.sort_values('popularity' , ascending = True).head(10)
sorted_df
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# 74961                              Breeze  6v126eNn1A79yFIKGfvqLz           0
# 74962                            Woodland  7qR2PWbDeuhh1Vzd0anb25           0
# 74963              Cool Me - Instrumental  0V3Q9RYUaiLKTJIvg4KCST           0
# 74964           The Tortoise and the Hare  0oX193rf5y87RipsZnH8Pq           0
# 56153                     Lié par le sang  3GO9Wo14FvMXvOKE4LItjg           0
# 74966                            Forsaken  1rRNU87xfqvxiUsEXXyi8k           0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0            0.6110         0.389        99373  0.9100          0.000000  C#
# 74954        0.1390         0.556       150487  0.4390          0.006400   D
# 74958        0.2130         0.736       212547  0.4460          0.821000   D
# 74959        0.0131         0.639       184000  0.8440          0.095700  A#
# 74961        0.0280         0.607       147653  0.5540          0.000000   A
# 74962        0.9950         0.529       266067  0.1540          0.414000   B
# 74963        0.2500         0.623       350080  0.4710          0.931000  A#
# 74964        0.4960         0.563       201362  0.3460          0.000000   D
# 56153        0.0294         0.656       276027  0.6940          0.000017   A
# 74966        0.9940         0.429       129387  0.0382          0.000000   B
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0        0.3460    -1.828  Major       0.0525  166.969            4/4    0.814
# 74954    0.1720   -11.604  Major       0.0288  165.306            4/4    0.820
# 74958    0.2980   -12.328  Major       0.0504  130.011            4/4    0.668
# 74959    0.0399    -8.582  Minor       0.0439  120.027            4/4    0.271
# 74961    0.1690   -10.571  Major       0.3710   92.193            4/4    0.404
# 74962    0.1230    -9.222  Minor       0.0470   69.588            4/4    0.332
# 74963    0.2580    -8.675  Major       0.0332  120.015            4/4    0.515
# 74964    0.1200   -14.058  Major       0.0938  144.642            4/4    0.370
# 56153    0.0527    -6.755  Major       0.0273  120.085            4/4    0.449
# 74966    0.4480   -12.704  Major       0.0557  156.807            3/4    0.474

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# popularity            29.0000      43.000000      55.0000      100.000
# acousticness           0.0376       0.232000       0.7220        0.996
# danceability           0.4350       0.571000       0.6920        0.989
# duration_ms       182857.0000  220427.000000  265768.0000  5552917.000
# energy                 0.3850       0.605000       0.7870        0.999
# instrumentalness       0.0000       0.000044       0.0358        0.999
# liveness               0.0974       0.128000       0.2640        1.000
# loudness             -11.7710      -7.762000      -5.5010        3.744
# speechiness            0.0367       0.050100       0.1050        0.967
# tempo                 92.9590     115.778000     139.0540      242.903
# valence                0.2370       0.444000       0.6600        1.000

# %%
most_popular =df_tracks.query('popularity>90',inplace=False).sort_values('popularity',ascending=False)
most_popular[:10]
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107802       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 138918                                      Con Calma  5w9c2J52mkdntKOmRLeM2m
# 66643                                       Con Calma  5w9c2J52mkdntKOmRLeM2m
# 107909                                      Con Calma  5w9c2J52mkdntKOmRLeM2m
# 86953   Sunflower - Spider-Man: Into the Spider-Verse  3KkXRkHbMCARz0aVfEt68P
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 107804         100        0.5780         0.725       178640   0.321
# 9027           100        0.5780         0.725       178640   0.321
# 9026            99        0.0421         0.726       190440   0.554
# 86951           99        0.1630         0.833       149520   0.539
# 107803          99        0.1630         0.833       149520   0.539
# 107802          99        0.0421         0.726       190440   0.554
# 138918          98        0.1100         0.737       193227   0.860
# 66643           98        0.1100         0.737       193227   0.860
# 107909          98        0.1100         0.737       193227   0.860
# 86953           97        0.5560         0.760       158040   0.479
#
#         instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 107804          0.000000  C#    0.0884   -10.744  Minor       0.3230   70.142
# 9027            0.000000  C#    0.0884   -10.744  Minor       0.3230   70.142
# 9026            0.000000   F    0.1060    -5.290  Minor       0.0917  169.999
# 86951           0.000002   B    0.1010    -7.399  Minor       0.1780   99.947
# 107803          0.000002   B    0.1010    -7.399  Minor       0.1780   99.947
# 107802          0.000000   F    0.1060    -5.290  Minor       0.0917  169.999
# 138918          0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 66643           0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 107909          0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 86953           0.000000   D    0.0703    -5.574  Major       0.0466   89.911
#
#        time_signature  valence
# 107804            4/4    0.319
# 9027              4/4    0.319
# 9026              4/4    0.335
# 86951             4/4    0.385
# 107803            4/4    0.385
# 107802            4/4    0.335
# 138918            4/4    0.656
# 66643             4/4    0.656
# 107909            4/4    0.656
# 86953             4/4    0.913

# %%
df_tracks.set_index("release_date", inplace=True)
df_tracks.index=pd.to_datetime(df_tracks.index)
df_tracks.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_tracks.set_index("release_date", inplace=True)
#       2 df_tracks.index=pd.to_datetime(df_tracks.index)
#       3 df_tracks.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['release_date'] are in the columns"

# %%
df_tracks[["artist_name"]].iloc[18]
# Out:
# artist_name    Henri Salvador
# Name: 18, dtype: object

# %%
df_tracks["duration"]= df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms", inplace=True, axis=1)
df_tracks.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
df_tracks.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
corr_df=df_tracks.drop(["key","mode"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=". 1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1,linecolor="Black")
heatmap.set_title("Correlation HeatMap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 corr_df=df_tracks.drop(["key","mode"],axis=1).corr(method="pearson")
#       2 plt.figure(figsize=(14,6))
# ----> 3 heatmap=sns.heatmap(corr_df,annot=True,fmt=". 1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1,linecolor="Black")
#       4 heatmap.set_title("Correlation HeatMap Between Variable")
#       5 heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551 if square:
#     552     ax.set_aspect("equal")
# --> 553 plotter.plot(ax, cbar_ax, kwargs)
#     554 return ax
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:348, in _HeatMapper.plot(self, ax, cax, kws)
#     346 # Annotate the cells with the formatted values
#     347 if self.annot:
# --> 348     self._annotate_heatmap(ax, mesh)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:256, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     254 lum = relative_luminance(color)
#     255 text_color = ".15" if lum > .408 else "w"
# --> 256 annotation = ("{:" + self.fmt + "}").format(val)
#     257 text_kwargs = dict(color=text_color, ha="center", va="center")
#     258 text_kwargs.update(self.annot_kws)
#
# ValueError: Format specifier missing precision

# %%
sample_df = df_tracks.sample(int(0.004*len(df_tracks)))

# %%
print(len(sample_df))
# Out:
# 930

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="loudness vs energy")
# Out:
# [Text(0.5, 1.0, 'loudness vs energy')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="b").set(title="popularity vs acousticness")
# Out:
# [Text(0.5, 1.0, 'popularity vs acousticness')]

# %%
df_tracks['dates']=df_tracks.index.get_level_values('release_date')
df_tracks.dates=pd.to_datetime(df_tracks.dates)
years=df_tracks.dates.dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 df_tracks['dates']=df_tracks.index.get_level_values('release_date')
#       2 df_tracks.dates=pd.to_datetime(df_tracks.dates)
#       3 years=df_tracks.dates.dt.year
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:2008, in Index._get_level_values(self, level)
#    1972 def _get_level_values(self, level) -> Index:
#    1973     """
#    1974     Return an Index of values for requested level.
#    1975
#    (...)
#    2006     Index(['a', 'b', 'c'], dtype='object')
#    2007     """
# -> 2008     self._validate_index_level(level)
#    2009     return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:1931, in Index._validate_index_level(self, level)
#    1927         raise IndexError(
#    1928             f"Too many levels: Index has only 1 level, not {level + 1}"
#    1929         )
#    1930 elif level != self.name:
# -> 1931     raise KeyError(
#    1932         f"Requested level ({level}) does not match index name ({self.name})"
#    1933     )
#
# KeyError: 'Requested level (release_date) does not match index name (None)'

# %%
pip install --user seaborn==0.11.0
# Out:
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 8.7 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from seaborn==0.11.0) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from seaborn==0.11.0) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from seaborn==0.11.0) (1.4.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from seaborn==0.11.0) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn==0.11.0) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn==0.11.0) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/alvinsamueljeyachander/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.0) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.displot(years,discrete=True,aspect=2,height=5,kind="hist").set(title="Number of songs per year")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 sns.displot(years,discrete=True,aspect=2,height=5,kind="hist").set(title="Number of songs per year")
#
# NameError: name 'years' is not defined

# %%
total_dr=df_tracks.duration
fig_dims=(18,7)
fig, ax=plt.subplots(figsize=fig_dims)
fig=sns.barplot(x=years,y=total_dr,ax=ax,errwidth=False).set(title="year vs Duration")
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 4>()
#       2 fig_dims=(18,7)
#       3 fig, ax=plt.subplots(figsize=fig_dims)
# ----> 4 fig=sns.barplot(x=years,y=total_dr,ax=ax,errwidth=False).set(title="year vs Duration")
#       5 plt.xticks(rotation=90)
#
# NameError: name 'years' is not defined
